# %%
f = open("data.txt", "r")
for x in f:
    x = x.split(",")
    x[0]=float(x[0])
    x[1]=float(x[1][:-1])
    data.append(x)
f.close
data=data[1:]
#print(data)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.axes(projection = 'polar')
  
# setting the radius
r = 10
  
# creating an array containing the
# radian values
rads = np.arange(0, (2 * np.pi), 0.01)

for i in data:
    if(i[1]<=1000):
        plt.polar((i[0]*np.pi/180), i[1], 'r.')

plt.show()
